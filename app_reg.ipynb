# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
import pickle

# %%
df = pd.read_csv("insulin_dosage_prediction.csv")
df.drop(['patient_id'],axis=1,inplace=True)
df.columns
# Out:
# Index(['gender', 'age', 'family_history', 'glucose_level', 'physical_activity',
#        'food_intake', 'previous_medications', 'BMI', 'HbA1c', 'weight',
#        'insulin_sensitivity', 'sleep_hours', 'creatinine', 'Insulin'],
#       dtype='object')

# %%
df.head()
# Out:
#    gender  age family_history  glucose_level  physical_activity food_intake  \
# 0    male   68            yes         103.49               9.28        high
# 1  female   57            yes         113.35               6.67        high
# 2    male   24            yes         127.40               4.14      medium
# 3    male   49            yes         138.79               6.80      medium
# 4    male   65             no         128.42               4.01         low
#
#   previous_medications    BMI  HbA1c  weight  insulin_sensitivity  \
# 0                 none  33.87   7.42   54.77                 1.49
# 1              insulin  19.10  11.66  114.93                 1.35
# 2                 oral  22.48   5.72   59.07                 0.96
# 3                 oral  31.67  11.91   50.81                 0.61
# 4              insulin  28.50   5.72   65.95                 1.16
#
#    sleep_hours  creatinine Insulin
# 0         6.07        0.63  steady
# 1         8.60        1.08      up
# 2         5.19        1.36      up
# 3         4.79        1.23      up
# 4         7.68        0.62  steady

# %%
gender_label =LabelEncoder()
df['gender']=gender_label.fit_transform(df['gender'])
family_history_label =LabelEncoder()
df['family_history']=family_history_label.fit_transform(df['family_history'])
Insulin_label =LabelEncoder()
df['Insulin']=Insulin_label.fit_transform(df['Insulin'])
food_intake_label =LabelEncoder()
df['food_intake']=food_intake_label.fit_transform(df['food_intake'])
previous_medications_label =LabelEncoder()
df['previous_medications']=previous_medications_label.fit_transform(df['previous_medications'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   gender                10000 non-null  int32
#  1   age                   10000 non-null  int64
#  2   family_history        10000 non-null  int32
#  3   glucose_level         10000 non-null  float64
#  4   physical_activity     10000 non-null  float64
#  5   food_intake           10000 non-null  int32
#  6   previous_medications  10000 non-null  int32
#  7   BMI                   10000 non-null  float64
#  8   HbA1c                 10000 non-null  float64
#  9   weight                10000 non-null  float64
#  10  insulin_sensitivity   10000 non-null  float64
#  11  sleep_hours           10000 non-null  float64
#  12  creatinine            10000 non-null  float64
#  13  Insulin               10000 non-null  int32
# dtypes: float64(8), int32(5), int64(1)
# memory usage: 898.6 KB

# %%
# ---- SAVE ALL ENCODERS ----
with open("gender_label.pkl", "wb") as f:
    pickle.dump(gender_label, f)

with open("family_history_label.pkl", "wb") as f:
    pickle.dump(family_history_label, f)

with open("Insulin_label.pkl", "wb") as f:
    pickle.dump(Insulin_label, f)

with open("food_intake_label.pkl", "wb") as f:
    pickle.dump(food_intake_label, f)

with open("previous_medications.pkl", "wb") as f:
    pickle.dump(previous_medications_label, f)

# %%
x = df.drop('glucose_level', axis=1)
y = df['glucose_level']
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=0.8, random_state=42)

# %%
x.columns
# Out:
# Index(['gender', 'age', 'family_history', 'physical_activity', 'food_intake',
#        'previous_medications', 'BMI', 'HbA1c', 'weight', 'insulin_sensitivity',
#        'sleep_hours', 'creatinine', 'Insulin'],
#       dtype='object')

# %%
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
# Transform x_test using the same scaler
x_test_scaled = scaler.transform(x_test)

# %%
with open("scaler.pkl", "wb") as f:
    pickle.dump(scaler, f)

# %% [markdown]
# # ANN

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping , TensorBoard
import datetime

# %%
model = Sequential([
    Dense(64, activation='relu', input_shape=(x_train.shape[1],)),
    Dense(32, activation='relu'),
    Dense(1)
])
# Out:
# C:\Users\nithi\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_9 (Dense)                 │ (None, 64)             │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,009 (11.75 KB)
#  Trainable params: 3,009 (11.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
opt =tf.keras.optimizers.Adam(learning_rate=.01)
loss =tf.keras.losses.BinaryCrossentropy()

# %%
# Compile the model
model.compile(optimizer=opt,loss = "mse", metrics=['mse'])

# %%
# Set the Tensorboard

log_dir = 'logs/fit/'+datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensor_flow_callback =TensorBoard(log_dir=log_dir, histogram_freq=1)

# %%
# Set Up Early Stopping 
early_stopping_callback =  EarlyStopping(monitor='val_loss', patience=50,  restore_best_weights=True)

# %%
history = model.fit(
    x_train_scaled, y_train,
    validation_data=(x_test_scaled, y_test),
    epochs=1000,
    callbacks=[tensor_flow_callback, early_stopping_callback])
# Out:
# Epoch 1/1000
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 3111.5117 - mse: 3111.5117 - val_loss: 1610.6816 - val_mse: 1610.6816
# Epoch 2/1000
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1498.3969 - mse: 1498.3969 - val_loss: 1505.4911 - val_mse: 1505.4911
# Epoch 3/1000
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1466.3665 - mse: 1466.3665 - val_loss: 1511.1222 - val_mse: 1511.1222
# Epoch 4/1000
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1460.3170 - mse: 1460.3170 - val_loss: 1499.7516 - val_mse: 1499.7516
# Epoch 5/1000
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1443.6887 - mse: 1443.6887 - val_loss: 1462.8541 - val_mse: 1462.8541
# Epoch 6/1000
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1437.1698 - mse: 1437.1698 - val_loss: 1471.5226 - val_mse: 1471.5226
# Epoch 7/1000
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1439.7694 - mse: 1439.7694 - val_loss: 1478.0887 - val_mse: 1478.0887
# Epoch 8/1000
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1436.7786 - mse: 1436.7786 - val_loss: 1483.4739 - val_mse: 1483.4739
# Epoch 9/1000
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1433.2249 - mse: 1433.2249 - val_loss: 1517.7726 - val_mse: 1517.7726
# Epoch 10/1000
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1420.9966 - mse: 1420.9966 - val_loss: 1464.0066 - val_mse: 1464.0066
# Epoch 11/1000
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1416.6205 - mse: 1416.6205 - val_loss: 1452.4459 - val_mse: 1452.4459
# Epoch 12/1000
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1415.3523 - mse: 1415.3523 - val_loss: 1462.0938 - val_mse: 1462.0938
# Epoch 13/1000
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1413.9562 - mse: 1413.9562 - val_loss: 1479.5049 - val_mse: 1479.5049
# Epoch 14/1000
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1412.8325 - mse: 1412.8325 - val_loss: 1453.9218 - val_mse: 1453.9218
# Epoch 15/1000
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1414.5236 - mse: 1414.5236 - val_loss: 1441.3260 - val_mse: 1441.3260
# Epoch 16/1000
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1410.6182 - mse: 1410.6182 - val_loss: 1468.3368 - val_mse: 1468.3368
# Epoch 17/1000
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1411.7550 - mse: 1411.7550 - val_loss: 1431.7450 - val_mse: 1431.7450
# Epoch 18/1000
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1418.9607 - mse: 1418.9607 - val_loss: 1486.0029 - val_mse: 1486.0029
# Epoch 19/1000
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1411.4705 - mse: 1411.4705 - val_loss: 1436.4468 - val_mse: 1436.4468
# Epoch 20/1000
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1400.8086 - mse: 1400.8086 - val_loss: 1451.7610 - val_mse: 1451.7610
# Epoch 21/1000
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1396.0471 - mse: 1396.0471 - val_loss: 1442.3079 - val_mse: 1442.3079
# Epoch 22/1000
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1402.7808 - mse: 1402.7808 - val_loss: 1434.2748 - val_mse: 1434.2748
# Epoch 23/1000
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 
1000
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1284.9983 - mse: 1284.9983 - val_loss: 1436.1511 - val_mse: 1436.1511
# Epoch 82/1000
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1276.5549 - mse: 1276.5549 - val_loss: 1435.4906 - val_mse: 1435.4906
# Epoch 83/1000
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1280.3114 - mse: 1280.3114 - val_loss: 1442.2463 - val_mse: 1442.2463
# Epoch 84/1000
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1277.4750 - mse: 1277.4750 - val_loss: 1455.0842 - val_mse: 1455.0842
# Epoch 85/1000
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1271.5354 - mse: 1271.5354 - val_loss: 1433.9142 - val_mse: 1433.9142
# Epoch 86/1000
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1271.5845 - mse: 1271.5845 - val_loss: 1450.5764 - val_mse: 1450.5764
# Epoch 87/1000
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1272.7701 - mse: 1272.7701 - val_loss: 1436.3921 - val_mse: 1436.3921
# Epoch 88/1000
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1273.7936 - mse: 1273.7936 - val_loss: 1448.4576 - val_mse: 1448.4576
# Epoch 89/1000
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1264.5568 - mse: 1264.5568 - val_loss: 1435.1847 - val_mse: 1435.1847
# Epoch 90/1000
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1262.4229 - mse: 1262.4229 - val_loss: 1474.1854 - val_mse: 1474.1854
# Epoch 91/1000
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1259.7468 - mse: 1259.7468 - val_loss: 1431.8167 - val_mse: 1431.8167
# Epoch 92/1000
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1259.1066 - mse: 1259.1066 - val_loss: 1443.8110 - val_mse: 1443.8110
# Epoch 93/1000
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1259.9318 - mse: 1259.9318 - val_loss: 1454.0636 - val_mse: 1454.0636
# Epoch 94/1000
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 1258.8337 - mse: 1258.8337 - val_loss: 1449.1069 - val_mse: 1449.1069
# Epoch 95/1000
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1249.6140 - mse: 1249.6140 - val_loss: 1447.9084 - val_mse: 1447.9084
# Epoch 96/1000
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1246.3119 - mse: 1246.3119 - val_loss: 1437.6157 - val_mse: 1437.6157

# %%
model.save('reg_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Load Tensorboard Extension
#%load_ext tensorboard

# %%
#%tensorboard --logdir  logs/fit

# %%
test_loss, test_mse=model.evaluate(x_test_scaled,y_test)
print(test_loss, test_mse)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1389.3044 - mse: 1389.3044
# 1389.304443359375 1389.304443359375

# %%
df_ = pd.read_csv("insulin_dosage_prediction.csv")

dict_ = {}
for col in df_.columns[1:]:   # skip first column, usually index/ID
    dict_[col] = df_[col].iloc[100]   # <-- FIXED (NO [0])

op = dict_.pop('glucose_level')  # remove insulin label from input
print(dict_,op)
# Out:
# {'gender': 'male', 'age': 65, 'family_history': 'no', 'physical_activity': 0.49, 'food_intake': 'low', 'previous_medications': 'insulin', 'BMI': 28.82, 'HbA1c': 8.99, 'weight': 59.02, 'insulin_sensitivity': 0.55, 'sleep_hours': 5.66, 'creatinine': 1.29, 'Insulin': 'up'} 174.02

# %%
gender_label.classes_
# Out:
# array(['female', 'male'], dtype=object)

# %%
import warnings
from tensorflow.keras.models import load_model
import pickle
import numpy as np

# Load model safely
model = load_model("reg_model.h5", compile=False)

# Recompile with proper regression loss/metrics
model.compile(
    optimizer="adam",
    loss="mean_squared_error",
    metrics=["mean_absolute_error"]
)

# Load encoders
with open('gender_label.pkl','rb') as file:
    gender_label = pickle.load(file)

with open('family_history_label.pkl','rb') as file:
    family_history_label = pickle.load(file)

with open('Insulin_label.pkl','rb') as file:
    Insulin_label = pickle.load(file)

with open('food_intake_label.pkl','rb') as file:
    food_intake_one = pickle.load(file)

with open('previous_medications.pkl','rb') as file:
    previous_medications = pickle.load(file)

# Label encoding
gender_enc = gender_label.transform([dict_['gender']])[0]
family_history_enc = family_history_label.transform([dict_['family_history']])[0]
food_intake_enc = food_intake_one.transform([dict_['food_intake']])[0]
previous_medications_enc = previous_medications.transform([dict_['previous_medications']])[0]
Insulin_label_enc = Insulin_label.transform([dict_['Insulin']])[0]

print("Gender Encoded:", gender_enc)
print("Family History Encoded:", family_history_enc)
print("Food Intake Encoded:", food_intake_enc)
print("Previous Medications Encoded:", previous_medications_enc)
print("Insulin :", Insulin_label_enc)
# Out:
# Gender Encoded: 1
# Family History Encoded: 0
# Food Intake Encoded: 1
# Previous Medications Encoded: 1
# Insulin : 3

# %%
dict_['gender'] = gender_enc
dict_['family_history'] = family_history_enc
dict_['food_intake'] = food_intake_enc
dict_['previous_medications'] = previous_medications_enc
dict_['Insulin'] = Insulin_label_enc

# %%
dict_
# Out:
# {'gender': 1,
#  'age': 65,
#  'family_history': 0,
#  'physical_activity': 0.49,
#  'food_intake': 1,
#  'previous_medications': 1,
#  'BMI': 28.82,
#  'HbA1c': 8.99,
#  'weight': 59.02,
#  'insulin_sensitivity': 0.55,
#  'sleep_hours': 5.66,
#  'creatinine': 1.29,
#  'Insulin': 3}

# %%
with open("scaler.pkl", "rb") as f:
    scaler = pickle.load(f)
scaler
# Out:
# StandardScaler()

# %%
# Prediction 
# Convert to numpy array in correct order
X = np.array(list(dict_.values())).reshape(1, -1)
X_scaled = scaler.transform(X)
# Prediction
pred = model.predict(X_scaled)
print((pred[0][0]))
#0.267092
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 146.8327
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
import warnings

warnings.filterwarnings("ignore", message="X does not have valid feature names*")

df_ = pd.read_csv("insulin_dosage_prediction.csv")

for i in range(20):
    dict_ = {}
    for col in df_.columns[1:]:   # skip first column, usually index/ID
        dict_[col] = df_[col].iloc[i]   # <-- FIXED (NO [0])
    
    op = dict_.pop('Insulin')  # remove insulin label from input
    print(dict_,op)
    
    # Label encoding
    gender_enc = gender_label.transform([dict_['gender']])[0]
    family_history_enc = family_history_label.transform([dict_['family_history']])[0]
    food_intake_enc = food_intake_one.transform([dict_['food_intake']])[0]
    previous_medications_enc = previous_medications.transform([dict_['previous_medications']])[0]

    dict_['gender'] = gender_enc
    dict_['family_history'] = family_history_enc
    dict_['food_intake'] = food_intake_enc
    dict_['previous_medications'] = previous_medications_enc

    #print(dict_)

    # Prediction 
    # Convert to numpy array in correct order
    X = np.array(list(dict_.values())).reshape(1, -1)
    X_scaled = scaler.transform(X)
    # Prediction
    pred = model.predict(X_scaled)
    
    pred_class = np.argmax(pred, axis=1)
    print("Predicted class index:", Insulin_label.classes_[pred_class[0]])    #0.267092
# Out:
# {'gender': 'male', 'age': 68, 'family_history': 'yes', 'glucose_level': 103.49, 'physical_activity': 9.28, 'food_intake': 'high', 'previous_medications': 'none', 'BMI': 33.87, 'HbA1c': 7.42, 'weight': 54.77, 'insulin_sensitivity': 1.49, 'sleep_hours': 6.07, 'creatinine': 0.63} steady
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Predicted class index: steady
# {'gender': 'female', 'age': 57, 'family_history': 'yes', 'glucose_level': 113.35, 'physical_activity': 6.67, 'food_intake': 'high', 'previous_medications': 'insulin', 'BMI': 19.1, 'HbA1c': 11.66, 'weight': 114.93, 'insulin_sensitivity': 1.35, 'sleep_hours': 8.6, 'creatinine': 1.08} up
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Predicted class index: up
# {'gender': 'male', 'age': 24, 'family_history': 'yes', 'glucose_level': 127.4, 'physical_activity': 4.14, 'food_intake': 'medium', 'previous_medications': 'oral', 'BMI': 22.48, 'HbA1c': 5.72, 'weight': 59.07, 'insulin_sensitivity': 0.96, 'sleep_hours': 5.19, 'creatinine': 1.36} up
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Predicted class index: up
# {'gender': 'male', 'age': 49, 'family_history': 'yes', 'glucose_level': 138.79, 'physical_activity': 6.8, 'food_intake': 'medium', 'previous_medications': 'oral', 'BMI': 31.67, 'HbA1c': 11.91, 'weight': 50.81, 'insulin_sensitivity': 0.61, 'sleep_hours': 4.79, 'creatinine': 1.23} up
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Predicted class index: up
# {'gender': 'male', 'age': 65, 'family_history': 'no', 'glucose_level': 128.42, 'physical_activity': 4.01, 'food_intake': 'low', 'previous_medications': 'insulin', 'BMI': 28.5, 'HbA1c': 5.72, 'weight': 65.95, 'insulin_sensitivity': 1.16, 'sleep_hours': 7.68, 'creatinine': 0.62} steady
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Predicted class index: steady
# {'gender': 'female', 'age': 36, 'family_history': 'yes', 'glucose_level': 134.12, 'physical_activity': 1.14, 'food_intake': 'medium', 'previous_medications': 'both', 'BMI': 31.3, 'HbA1c': 6.55, 'weight': 104.69, 'insulin_sensitivity': 0.92, 'sleep_hours': 5.79, 'creatinine': 1.17} up
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Predicted class index: up
# {'gender': 'male', 'age': 23, 'family_history': 'yes', 'glucose_level': 108.82, 'physical_activity': 7.19, 'food_intake': 'high', 'previous_medications': 'none', 'BMI': 19.96, 'HbA1c': 4.7, 'weight': 42.26, 'insulin_sensitivity': 0.91, 'sleep_hours': 7.68, 'creatinine': 1.3} up
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Predicted class index: up
# {'gender': 'male', 'age': 37, 'family_history': 'no', 'glucose_level': 90.67, 'physical_activity': 8.24, 'food_intake': 'high', 'previous_medications': 'oral', 'BMI': 32.35, 'HbA1c': 10.02, 'weight': 58.15, 'insulin_sensitivity': 0.84, 'sleep_hours': 5.89, 'creatinine': 0.88} steady
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Predicted class index: steady
# {'gender': 'male', 'age': 44, 'family_history': 'no', 'glucose_level': 76.16, 'physical_activity': 7.29, 'food_intake': 'high', 'previous_medications': 'insulin', 'BMI': 35.68, 'HbA1c': 4.14, 'weight': 116.45, 'insulin_sensitivity': 0.67, 'sleep_hours': 8.63, 'creatinine': 1.25} steady
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Predicted class index: steady
# {'gender': 'female', 'age': 70, 'family_history': 'yes', 'glucose_level': 95.48, 'physical_activity': 2.29, 'food_intake': 'medium', 'previous_medications': 'both', 'BMI': 30.02, 'HbA1c': 10.3, 'weight': 41.36, 'insulin_sensitivity': 0.59, 'sleep_hours': 6.53, 'creatinine': 1.21} up
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Predicted class index: up
# {'gender': 'male', 'age': 60, 'family_history': 'no', 'glucose_level': 145.65, 'physical_activity': 9.57, 'food_intake': 'high', 'previous_medications': 'oral', 'BMI': 25.86, 'HbA1c': 8.62, 'weight': 62.26, 'insulin_sensitivity': 1.32, 'sleep_hours': 9.92, 'creatinine': 0.83} steady
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Predicted class index: steady
# {'gender': 'male', 'age': 54, 'family_history': 'no', 'glucose_level': 172.2, 'physical_activity': 0.25, 'food_intake': 'medium', 'previous_medications': 'both', 'BMI': 21.84, 'HbA1c': 9.99, 'weight': 66.06, 'insulin_sensitivity': 0.68, 'sleep_hours': 6.25, 'creatinine': 1.24} steady
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Predicted class index: steady
# {'gender': 'male', 'age': 65, 'family_history': 'yes', 'glucose_level': 92.0, 'physical_activity': 3.33, 'food_intake': 'low', 'previous_medications': 'oral', 'BMI': 23.84, 'HbA1c': 10.26, 'weight': 113.91, 'insulin_sensitivity': 1.2, 'sleep_hours': 4.88, 'creatinine': 1.14} down
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Predicted class index: down
# {'gender': 'male', 'age': 24, 'family_history': 'no', 'glucose_level': 84.11, 'physical_activity': 2.6, 'food_intake': 'high', 'previous_medications': 'oral', 'BMI': 29.5, 'HbA1c': 5.0, 'weight': 108.1, 'insulin_sensitivity': 1.23, 'sleep_hours': 7.81, 'creatinine': 0.81} steady
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Predicted class index: steady
# {'gender': 'female', 'age': 76, 'family_history': 'yes', 'glucose_level': 167.41, 'physical_activity': 0.48, 'food_intake': 'low', 'previous_medications': 'both', 'BMI': 23.62, 'HbA1c': 4.17, 'weight': 76.81, 'insulin_sensitivity': 0.81, 'sleep_hours': 8.37, 'creatinine': 1.04} up
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Predicted class index: up
# {'gender': 'male', 'age': 22, 'family_history': 'yes', 'glucose_level': 109.67, 'physical_activity': 4.06, 'food_intake': 'high', 'previous_medications': 'none', 'BMI': 35.11, 'HbA1c': 5.35, 'weight': 65.4, 'insulin_sensitivity': 1.06, 'sleep_hours': 6.07, 'creatinine': 0.96} steady
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Predicted class index: steady
# {'gender': 'female', 'age': 28, 'family_history': 'no', 'glucose_level': 193.69, 'physical_activity': 6.23, 'food_intake': 'high', 'previous_medications': 'both', 'BMI': 20.9, 'HbA1c': 7.07, 'weight': 115.55, 'insulin_sensitivity': 1.21, 'sleep_hours': 8.48, 'creatinine': 0.55} steady
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Predicted class index: steady
# {'gender': 'female', 'age': 32, 'family_history': 'yes', 'glucose_level': 162.86, 'physical_activity': 8.83, 'food_intake': 'high', 'previous_medications': 'insulin', 'BMI': 29.36, 'HbA1c': 4.59, 'weight': 55.06, 'insulin_sensitivity': 0.63, 'sleep_hours': 6.05, 'creatinine': 1.18} up
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Predicted class index: up
# {'gender': 'female', 'age': 20, 'family_history': 'yes', 'glucose_level': 112.48, 'physical_activity': 9.9, 'food_intake': 'low', 'previous_medications': 'oral', 'BMI': 28.91, 'HbA1c': 7.65, 'weight': 78.15, 'insulin_sensitivity': 0.67, 'sleep_hours': 4.58, 'creatinine': 0.64} up
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Predicted class index: up
# {'gender': 'male', 'age': 75, 'family_history': 'no', 'glucose_level': 107.64, 'physical_activity': 8.08, 'food_intake': 'high', 'previous_medications': 'both', 'BMI': 21.06, 'HbA1c': 6.28, 'weight': 73.48, 'insulin_sensitivity': 1.22, 'sleep_hours': 4.5, 'creatinine': 0.74} steady
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Predicted class index: steady

# %%
with open('Insulin_label.pkl','rb') as file:
    Insulin_label = pickle.load(file)
Insulin_label.classes_
# Out:
# array(['down', 'no', 'steady', 'up'], dtype=object)
