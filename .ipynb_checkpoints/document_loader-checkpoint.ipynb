# %%
from langchain_community.document_loaders import TextLoader
text_loader = TextLoader('speech.txt')

# %%
text = text_loader.load()

# %%
text
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='Data Scientist with 4+ years of experience in developing data-driven models, performing advanced analytics, and delivering actionable business insights. Skilled in Python, MySQL, PySpark, and AWS with expertise in statistical modeling, machine learning, RAG development and data visualization . Experienced with tools such as Airflow, Airbyte, Apache Iceberg, Metabase, and Splunk for building robust data pipelines and enabling end-to-end data science solutions.\n')]

# %%
from langchain_community.document_loaders import PyPDFLoader
pdf = PyPDFLoader('Offer Letter.pdf')

# %%
pdf = pdf.load()

# %%
pdf
# Out:
# [Document(metadata={'producer': 'LibreOffice 7.6', 'creator': 'Writer', 'creationdate': '2024-07-12T15:50:55+05:30', 'author': 'Hernandez, Mikaela', 'source': 'Offer Letter.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='12 July 2024\nNithin kumar K R\nNo 1 \nKothanur\nChikkaballapur\nKarnataka  562105\nDear Nithin kumar,\n \nOffer Letter\nThis has reference to your application and subsequent interview you had with us. Further, we are pleased to offer you the post  \nof Consultant.\n \nKindly make a note that your tentative date of joining would be  29 July 2024  and the Company may be constrained to change  \nyour joining date due to the prevailing unprecedented situation. In that event, the Company shall duly inform you of the revised  \nDate of Joining. In case of any changes to the date of joining please inform us before the expected date of onboard. Failure to  \ninform us and no-show on the expected date of joining will efface this employment offer.\n \nYou shall be on probation for a period of six months starting from the date of your joining. Your performance during the probation  \nwill be appraised and, if found satisfactory, you will be confirmed in services. However, in the event of your performance found  \nnot to be satisfactory, your probation period could be further However, in the event of your performance found not to be  \nsatisfactory, your probation period could be further extended as it deem appropriate by management.\n \nOn Joining, your all-inclusive Cost to the Company (CTC) will be  INR 132917 per month (subject to deduction of tax and other  \nstatutory payments, as may be applicable) as per CTC Annexure. You will also be eligible for all the benefits introduced in the  \nCompany policies, as applicable to your grade.\n \nDuring the probationary period, either party will be entitled to terminate this contract of employment by issuing  15 days days prior \nnotice in writing to the other. After confirmation the termination of employment by either party shall be by issuing  60 days notice \nin writing to the other or salary in lieu thereof. In the event of you issuing a notice of termination shorter than the above period,  \nthe Company shall have its own discretion to adjust any leave due to you or recover from you such amount from your dues  \ntowards the shortfall in notice period.  However, acceptance of salary in lieu of notice period is at the sole discretion of the  \nCompany.\nIf in case, you resign within a year from the date of your joining, you will be liable to refund the reimbursements such as  \nrelocation expenses, joining bonus, travel expenses [including air & road], accommodation expenses and any other special  \nbenefits as per your eligibility, whichever was provided by the Company.\n \nPlease note that this employment is subject to  professional reference checks and documentary evidence of your previous  \nemployment. \nWe look forward to having you onboard.\nfor SPi Technologies India Private Limited\nManoj P\nVice President – Human Resources\nReceived the offer of employment and shall report for duty on the expected Date of Joining, as mentioned above.\n(Signature with date)'),
#  Document(metadata={'producer': 'LibreOffice 7.6', 'creator': 'Writer', 'creationdate': '2024-07-12T15:50:55+05:30', 'author': 'Hernandez, Mikaela', 'source': 'Offer Letter.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='Cost to the Company (CTC) Structure\nName                          :    Nithin kumar K R\nDesignation                :   Consultant\nDepartment                :    Data Analytics\nSALARY COMPUTATION\nComponents Annual Monthly\nBasic Pay 7,14,240 59,520\nHouse Rent Allowance 3,57,120 29,760\nSpecial Allowance 3,57,048 29,754\nGross Salary 14,28,408 1,19,034\nEmployer PF 21,600 1,800\nFixed CTC 14,50,008 1,20,834\nAPI 1,45,001 12,083\nTotal CTC 15,95,009 1,32,917\nEmployee PF 21,600 1,800\nPre Tax Take Home 14,06,808 1,17,234'),
#  Document(metadata={'producer': 'LibreOffice 7.6', 'creator': 'Writer', 'creationdate': '2024-07-12T15:50:55+05:30', 'author': 'Hernandez, Mikaela', 'source': 'Offer Letter.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='Annual Performance Incentive (API) will be paid as per Company’s policies based on Company and individual performance. You  \nwill be eligible from “0%” up to Maximum of “ 10 %”of your annual CTC and the API is subject to deduction of tax at source. You  \nwill be eligible for the pay-out subject to you being a confirmed employee as of 31st Dec and active on the rolls of the company  \nat the time of pay-out without serving any notice period.\nINR 1566009 is the indicative maximum annual earning potential.\nYou will also be eligible to the following on top of the above CTC:\n• Joining Bonus: INR  100000 will be paid after the successful completion of  one month  from the joining date (Subject to  \nappropriate tax) If in case, you resign from the company within 1 year of the date of receipt of the joining bonus the same is  \nrecoverable in full.\n• You will be covered in Group Mediclaim Insurance & Accident Policy Coverage as per policy terms and conditions as relevant \nto your job level/grade.\n• You will be eligible for payment of Gratuity as per the provisions of the Payment of Gratuity Act, 1972.\n• You shall be covered under Group Term Life Insurance (GTLI) policy for a Sum Insured of 2X of your Annual CTC.\nfor SPi Technologies India Private Limited \nManoj P\nVice President – Human Resources\nI accept the above CTC structure breakup and I am aware that this is confidential and shall not disclose this information to  \nothers.\nSignature of Acceptance with date')]

# %% [markdown]
# # Text Splitter

# %%
from langchain_community.document_loaders import PyPDFLoader
pdf = PyPDFLoader('Offer Letter.pdf')
pdf = pdf.load()

# %%
for i in pdf:
    print(i)
# Out:
# page_content='12 July 2024
# Nithin kumar K R
# No 1
# Kothanur
# Chikkaballapur
# Karnataka  562105
# Dear Nithin kumar,
#
# Offer Letter
# This has reference to your application and subsequent interview you had with us. Further, we are pleased to offer you the post
# of Consultant.
#
# Kindly make a note that your tentative date of joining would be  29 July 2024  and the Company may be constrained to change
# your joining date due to the prevailing unprecedented situation. In that event, the Company shall duly inform you of the revised
# Date of Joining. In case of any changes to the date of joining please inform us before the expected date of onboard. Failure to
# inform us and no-show on the expected date of joining will efface this employment offer.
#
# You shall be on probation for a period of six months starting from the date of your joining. Your performance during the probation
# will be appraised and, if found satisfactory, you will be confirmed in services. However, in the event of your performance found
# not to be satisfactory, your probation period could be further However, in the event of your performance found not to be
# satisfactory, your probation period could be further extended as it deem appropriate by management.
#
# On Joining, your all-inclusive Cost to the Company (CTC) will be  INR 132917 per month (subject to deduction of tax and other
# statutory payments, as may be applicable) as per CTC Annexure. You will also be eligible for all the benefits introduced in the
# Company policies, as applicable to your grade.
#
# During the probationary period, either party will be entitled to terminate this contract of employment by issuing  15 days days prior
# notice in writing to the other. After confirmation the termination of employment by either party shall be by issuing  60 days notice
# in writing to the other or salary in lieu thereof. In the event of you issuing a notice of termination shorter than the above period,
# the Company shall have its own discretion to adjust any leave due to you or recover from you such amount from your dues
# towards the shortfall in notice period.  However, acceptance of salary in lieu of notice period is at the sole discretion of the
# Company.
# If in case, you resign within a year from the date of your joining, you will be liable to refund the reimbursements such as
# relocation expenses, joining bonus, travel expenses [including air & road], accommodation expenses and any other special
# benefits as per your eligibility, whichever was provided by the Company.
#
# Please note that this employment is subject to  professional reference checks and documentary evidence of your previous
# employment.
# We look forward to having you onboard.
# for SPi Technologies India Private Limited
# Manoj P
# Vice President – Human Resources
# Received the offer of employment and shall report for duty on the expected Date of Joining, as mentioned above.
# (Signature with date)' metadata={'producer': 'LibreOffice 7.6', 'creator': 'Writer', 'creationdate': '2024-07-12T15:50:55+05:30', 'author': 'Hernandez, Mikaela', 'source': 'Offer Letter.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}
# page_content='Cost to the Company (CTC) Structure
# Name                          :    Nithin kumar K R
# Designation                :   Consultant
# Department                :    Data Analytics
# SALARY COMPUTATION
# Components Annual Monthly
# Basic Pay 7,14,240 59,520
# House Rent Allowance 3,57,120 29,760
# Special Allowance 3,57,048 29,754
# Gross Salary 14,28,408 1,19,034
# Employer PF 21,600 1,800
# Fixed CTC 14,50,008 1,20,834
# API 1,45,001 12,083
# Total CTC 15,95,009 1,32,917
# Employee PF 21,600 1,800
# Pre Tax Take Home 14,06,808 1,17,234' metadata={'producer': 'LibreOffice 7.6', 'creator': 'Writer', 'creationdate': '2024-07-12T15:50:55+05:30', 'author': 'Hernandez, Mikaela', 'source': 'Offer Letter.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}
# page_content='Annual Performance Incentive (API) will be paid as per Company’s policies based on Company and individual performance. You
# will be eligible from “0%” up to Maximum of “ 10 %”of your annual CTC and the API is subject to deduction of tax at source. You
# will be eligible for the pay-out subject to you being a confirmed employee as of 31st Dec and active on the rolls of the company
# at the time of pay-out without serving any notice period.
# INR 1566009 is the indicative maximum annual earning potential.
# You will also be eligible to the following on top of the above CTC:
# • Joining Bonus: INR  100000 will be paid after the successful completion of  one month  from the joining date (Subject to
# appropriate tax) If in case, you resign from the company within 1 year of the date of receipt of the joining bonus the same is
# recoverable in full.
# • You will be covered in Group Mediclaim Insurance & Accident Policy Coverage as per policy terms and conditions as relevant
# to your job level/grade.
# • You will be eligible for payment of Gratuity as per the provisions of the Payment of Gratuity Act, 1972.
# • You shall be covered under Group Term Life Insurance (GTLI) policy for a Sum Insured of 2X of your Annual CTC.
# for SPi Technologies India Private Limited
# Manoj P
# Vice President – Human Resources
# I accept the above CTC structure breakup and I am aware that this is confidential and shall not disclose this information to
# others.
# Signature of Acceptance with date' metadata={'producer': 'LibreOffice 7.6', 'creator': 'Writer', 'creationdate': '2024-07-12T15:50:55+05:30', 'author': 'Hernandez, Mikaela', 'source': 'Offer Letter.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}

# %% [markdown]
# # RecursiveCharacterTextSplitter

# %%
from langchain_text_splitters import  RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=100)
text_splitter.split_documents(pdf)
# Out:
# [Document(metadata={'producer': 'LibreOffice 7.6', 'creator': 'Writer', 'creationdate': '2024-07-12T15:50:55+05:30', 'author': 'Hernandez, Mikaela', 'source': 'Offer Letter.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='12 July 2024\nNithin kumar K R\nNo 1 \nKothanur\nChikkaballapur\nKarnataka  562105\nDear Nithin kumar,\n \nOffer Letter\nThis has reference to your application and subsequent interview you had with us. Further, we are pleased to offer you the post  \nof Consultant.\n \nKindly make a note that your tentative date of joining would be  29 July 2024  and the Company may be constrained to change'),
#  Document(metadata={'producer': 'LibreOffice 7.6', 'creator': 'Writer', 'creationdate': '2024-07-12T15:50:55+05:30', 'author': 'Hernandez, Mikaela', 'source': 'Offer Letter.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='your joining date due to the prevailing unprecedented situation. In that event, the Company shall duly inform you of the revised  \nDate of Joining. In case of any changes to the date of joining please inform us before the expected date of onboard. Failure to  \ninform us and no-show on the expected date of joining will efface this employment offer.\n \nYou shall be on probation for a period of six months starting from the date of your joining. Your performance during the probation'),
#  Document(metadata={'producer': 'LibreOffice 7.6', 'creator': 'Writer', 'creationdate': '2024-07-12T15:50:55+05:30', 'author': 'Hernandez, Mikaela', 'source': 'Offer Letter.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='will be appraised and, if found satisfactory, you will be confirmed in services. However, in the event of your performance found  \nnot to be satisfactory, your probation period could be further However, in the event of your performance found not to be  \nsatisfactory, your probation period could be further extended as it deem appropriate by management.\n \nOn Joining, your all-inclusive Cost to the Company (CTC) will be  INR 132917 per month (subject to deduction of tax and other'),
#  Document(metadata={'producer': 'LibreOffice 7.6', 'creator': 'Writer', 'creationdate': '2024-07-12T15:50:55+05:30', 'author': 'Hernandez, Mikaela', 'source': 'Offer Letter.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='statutory payments, as may be applicable) as per CTC Annexure. You will also be eligible for all the benefits introduced in the  \nCompany policies, as applicable to your grade.\n \nDuring the probationary period, either party will be entitled to terminate this contract of employment by issuing  15 days days prior \nnotice in writing to the other. After confirmation the termination of employment by either party shall be by issuing  60 days notice'),
#  Document(metadata={'producer': 'LibreOffice 7.6', 'creator': 'Writer', 'creationdate': '2024-07-12T15:50:55+05:30', 'author': 'Hernandez, Mikaela', 'source': 'Offer Letter.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='in writing to the other or salary in lieu thereof. In the event of you issuing a notice of termination shorter than the above period,  \nthe Company shall have its own discretion to adjust any leave due to you or recover from you such amount from your dues  \ntowards the shortfall in notice period.  However, acceptance of salary in lieu of notice period is at the sole discretion of the  \nCompany.'),
#  Document(metadata={'producer': 'LibreOffice 7.6', 'creator': 'Writer', 'creationdate': '2024-07-12T15:50:55+05:30', 'author': 'Hernandez, Mikaela', 'source': 'Offer Letter.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='Company.\nIf in case, you resign within a year from the date of your joining, you will be liable to refund the reimbursements such as  \nrelocation expenses, joining bonus, travel expenses [including air & road], accommodation expenses and any other special  \nbenefits as per your eligibility, whichever was provided by the Company.\n \nPlease note that this employment is subject to  professional reference checks and documentary evidence of your previous  \nemployment.'),
#  Document(metadata={'producer': 'LibreOffice 7.6', 'creator': 'Writer', 'creationdate': '2024-07-12T15:50:55+05:30', 'author': 'Hernandez, Mikaela', 'source': 'Offer Letter.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='employment. \nWe look forward to having you onboard.\nfor SPi Technologies India Private Limited\nManoj P\nVice President – Human Resources\nReceived the offer of employment and shall report for duty on the expected Date of Joining, as mentioned above.\n(Signature with date)'),
#  Document(metadata={'producer': 'LibreOffice 7.6', 'creator': 'Writer', 'creationdate': '2024-07-12T15:50:55+05:30', 'author': 'Hernandez, Mikaela', 'source': 'Offer Letter.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='Cost to the Company (CTC) Structure\nName                          :    Nithin kumar K R\nDesignation                :   Consultant\nDepartment                :    Data Analytics\nSALARY COMPUTATION\nComponents Annual Monthly\nBasic Pay 7,14,240 59,520\nHouse Rent Allowance 3,57,120 29,760\nSpecial Allowance 3,57,048 29,754\nGross Salary 14,28,408 1,19,034\nEmployer PF 21,600 1,800\nFixed CTC 14,50,008 1,20,834\nAPI 1,45,001 12,083\nTotal CTC 15,95,009 1,32,917\nEmployee PF 21,600 1,800'),
#  Document(metadata={'producer': 'LibreOffice 7.6', 'creator': 'Writer', 'creationdate': '2024-07-12T15:50:55+05:30', 'author': 'Hernandez, Mikaela', 'source': 'Offer Letter.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='API 1,45,001 12,083\nTotal CTC 15,95,009 1,32,917\nEmployee PF 21,600 1,800\nPre Tax Take Home 14,06,808 1,17,234'),
#  Document(metadata={'producer': 'LibreOffice 7.6', 'creator': 'Writer', 'creationdate': '2024-07-12T15:50:55+05:30', 'author': 'Hernandez, Mikaela', 'source': 'Offer Letter.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='Annual Performance Incentive (API) will be paid as per Company’s policies based on Company and individual performance. You  \nwill be eligible from “0%” up to Maximum of “ 10 %”of your annual CTC and the API is subject to deduction of tax at source. You  \nwill be eligible for the pay-out subject to you being a confirmed employee as of 31st Dec and active on the rolls of the company  \nat the time of pay-out without serving any notice period.'),
#  Document(metadata={'producer': 'LibreOffice 7.6', 'creator': 'Writer', 'creationdate': '2024-07-12T15:50:55+05:30', 'author': 'Hernandez, Mikaela', 'source': 'Offer Letter.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='at the time of pay-out without serving any notice period.\nINR 1566009 is the indicative maximum annual earning potential.\nYou will also be eligible to the following on top of the above CTC:\n• Joining Bonus: INR  100000 will be paid after the successful completion of  one month  from the joining date (Subject to  \nappropriate tax) If in case, you resign from the company within 1 year of the date of receipt of the joining bonus the same is  \nrecoverable in full.'),
#  Document(metadata={'producer': 'LibreOffice 7.6', 'creator': 'Writer', 'creationdate': '2024-07-12T15:50:55+05:30', 'author': 'Hernandez, Mikaela', 'source': 'Offer Letter.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='recoverable in full.\n• You will be covered in Group Mediclaim Insurance & Accident Policy Coverage as per policy terms and conditions as relevant \nto your job level/grade.\n• You will be eligible for payment of Gratuity as per the provisions of the Payment of Gratuity Act, 1972.\n• You shall be covered under Group Term Life Insurance (GTLI) policy for a Sum Insured of 2X of your Annual CTC.\nfor SPi Technologies India Private Limited \nManoj P\nVice President – Human Resources'),
#  Document(metadata={'producer': 'LibreOffice 7.6', 'creator': 'Writer', 'creationdate': '2024-07-12T15:50:55+05:30', 'author': 'Hernandez, Mikaela', 'source': 'Offer Letter.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='for SPi Technologies India Private Limited \nManoj P\nVice President – Human Resources\nI accept the above CTC structure breakup and I am aware that this is confidential and shall not disclose this information to  \nothers.\nSignature of Acceptance with date')]

# %% [markdown]
# # CharacterTextSplitter

# %%
from langchain_text_splitters import  CharacterTextSplitter
text_splitter = CharacterTextSplitter(separator= '\n\n' ,chunk_size=100, chunk_overlap=10)
for i in text_splitter.split_documents(pdf):
    print(i)
    print('-'*100)
# Out:
# page_content='12 July 2024
# Nithin kumar K R
# No 1
# Kothanur
# Chikkaballapur
# Karnataka  562105
# Dear Nithin kumar,
#
# Offer Letter
# This has reference to your application and subsequent interview you had with us. Further, we are pleased to offer you the post
# of Consultant.
#
# Kindly make a note that your tentative date of joining would be  29 July 2024  and the Company may be constrained to change
# your joining date due to the prevailing unprecedented situation. In that event, the Company shall duly inform you of the revised
# Date of Joining. In case of any changes to the date of joining please inform us before the expected date of onboard. Failure to
# inform us and no-show on the expected date of joining will efface this employment offer.
#
# You shall be on probation for a period of six months starting from the date of your joining. Your performance during the probation
# will be appraised and, if found satisfactory, you will be confirmed in services. However, in the event of your performance found
# not to be satisfactory, your probation period could be further However, in the event of your performance found not to be
# satisfactory, your probation period could be further extended as it deem appropriate by management.
#
# On Joining, your all-inclusive Cost to the Company (CTC) will be  INR 132917 per month (subject to deduction of tax and other
# statutory payments, as may be applicable) as per CTC Annexure. You will also be eligible for all the benefits introduced in the
# Company policies, as applicable to your grade.
#
# During the probationary period, either party will be entitled to terminate this contract of employment by issuing  15 days days prior
# notice in writing to the other. After confirmation the termination of employment by either party shall be by issuing  60 days notice
# in writing to the other or salary in lieu thereof. In the event of you issuing a notice of termination shorter than the above period,
# the Company shall have its own discretion to adjust any leave due to you or recover from you such amount from your dues
# towards the shortfall in notice period.  However, acceptance of salary in lieu of notice period is at the sole discretion of the
# Company.
# If in case, you resign within a year from the date of your joining, you will be liable to refund the reimbursements such as
# relocation expenses, joining bonus, travel expenses [including air & road], accommodation expenses and any other special
# benefits as per your eligibility, whichever was provided by the Company.
#
# Please note that this employment is subject to  professional reference checks and documentary evidence of your previous
# employment.
# We look forward to having you onboard.
# for SPi Technologies India Private Limited
# Manoj P
# Vice President – Human Resources
# Received the offer of employment and shall report for duty on the expected Date of Joining, as mentioned above.
# (Signature with date)' metadata={'producer': 'LibreOffice 7.6', 'creator': 'Writer', 'creationdate': '2024-07-12T15:50:55+05:30', 'author': 'Hernandez, Mikaela', 'source': 'Offer Letter.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}
# ----------------------------------------------------------------------------------------------------
# page_content='Cost to the Company (CTC) Structure
# Name                          :    Nithin kumar K R
# Designation                :   Consultant
# Department                :    Data Analytics
# SALARY COMPUTATION
# Components Annual Monthly
# Basic Pay 7,14,240 59,520
# House Rent Allowance 3,57,120 29,760
# Special Allowance 3,57,048 29,754
# Gross Salary 14,28,408 1,19,034
# Employer PF 21,600 1,800
# Fixed CTC 14,50,008 1,20,834
# API 1,45,001 12,083
# Total CTC 15,95,009 1,32,917
# Employee PF 21,600 1,800
# Pre Tax Take Home 14,06,808 1,17,234' metadata={'producer': 'LibreOffice 7.6', 'creator': 'Writer', 'creationdate': '2024-07-12T15:50:55+05:30', 'author': 'Hernandez, Mikaela', 'source': 'Offer Letter.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}
# ----------------------------------------------------------------------------------------------------
# page_content='Annual Performance Incentive (API) will be paid as per Company’s policies based on Company and individual performance. You
# will be eligible from “0%” up to Maximum of “ 10 %”of your annual CTC and the API is subject to deduction of tax at source. You
# will be eligible for the pay-out subject to you being a confirmed employee as of 31st Dec and active on the rolls of the company
# at the time of pay-out without serving any notice period.
# INR 1566009 is the indicative maximum annual earning potential.
# You will also be eligible to the following on top of the above CTC:
# • Joining Bonus: INR  100000 will be paid after the successful completion of  one month  from the joining date (Subject to
# appropriate tax) If in case, you resign from the company within 1 year of the date of receipt of the joining bonus the same is
# recoverable in full.
# • You will be covered in Group Mediclaim Insurance & Accident Policy Coverage as per policy terms and conditions as relevant
# to your job level/grade.
# • You will be eligible for payment of Gratuity as per the provisions of the Payment of Gratuity Act, 1972.
# • You shall be covered under Group Term Life Insurance (GTLI) policy for a Sum Insured of 2X of your Annual CTC.
# for SPi Technologies India Private Limited
# Manoj P
# Vice President – Human Resources
# I accept the above CTC structure breakup and I am aware that this is confidential and shall not disclose this information to
# others.
# Signature of Acceptance with date' metadata={'producer': 'LibreOffice 7.6', 'creator': 'Writer', 'creationdate': '2024-07-12T15:50:55+05:30', 'author': 'Hernandez, Mikaela', 'source': 'Offer Letter.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# #  HTMLHeaderTextSplitter

# %%
from langchain_text_splitters import  HTMLHeaderTextSplitter
string = """
<!DOCTYPE html>
<html>
<head>
    <title>My First Page</title>
</head>
<body>

    <h1>Hello World!</h1>
    <p>This is my first simple HTML page.</p

    <button>Click Me</button>

</body>
</html>
"""

header_split =[("h1","Header 1")]
html_string = HTMLHeaderTextSplitter(header_split)
docs = html_string.split_text(string)

for doc in docs:
    print("\nMETADATA:", doc.metadata)
    print("CONTENT:", doc.page_content)
# Out:
# METADATA: {}
# CONTENT: Click Me
#
# METADATA: {'Header 1': 'Hello World!'}
# CONTENT: Hello World!
#
# METADATA: {'Header 1': 'Hello World!'}
# CONTENT: This is my first simple HTML page.

# %%
#

# %%
import json
import requests
json_data = requests.get("https://api.smith.langchain.com/openapi.json").json()

# %%
from langchain_text_splitters import  RecursiveJsonSplitter
json_split = RecursiveJsonSplitter(max_chunk_size=300)
json_chucks = json_split.split_json(json_data)
for i in json_chucks[:5]:
    print(i,'\n')
    print('*'*100)
# Out:
# {'openapi': '3.1.0', 'info': {'title': 'LangSmith', 'description': 'The LangSmith API is used to programmatically create and manage LangSmith resources.\n\n## Host\nhttps://api.smith.langchain.com\n\n## Authentication\nTo authenticate with the LangSmith API, set the `X-Api-Key` header\nto a valid [LangSmith API key](https://docs.langchain.com/langsmith/create-account-api-key#create-an-api-key).\n\n'}}
#
# ****************************************************************************************************
# {'info': {'version': '0.1.0'}, 'paths': {'/api/v1/audit-logs': {'get': {'tags': ['audit-logs'], 'summary': 'Get Audit Logs'}}}}
#
# ****************************************************************************************************
# {'paths': {'/api/v1/audit-logs': {'get': {'description': "Retrieve audit log records for the authenticated user's organization in OCSF format.\n\nRequires both start_time and end_time parameters to filter logs within a date range.\nSupports cursor-based pagination.\n\nReturns results in OCSF API Activity (Class UID: 6003) format,\nwhich is compatible with security monitoring and SIEM tools.\nReference: https://schema.ocsf.io/1.7.0/classes/api_activity"}}}}
#
# ****************************************************************************************************
# {'paths': {'/api/v1/audit-logs': {'get': {'operationId': 'get_audit_logs_api_v1_audit_logs_get', 'security': [{'API Key': []}, {'Organization ID': []}, {'Bearer Auth': []}]}}}}
#
# ****************************************************************************************************
# {'paths': {'/api/v1/audit-logs': {'get': {'parameters': [{'name': 'limit', 'in': 'query', 'required': False, 'schema': {'type': 'integer', 'maximum': 100, 'minimum': 1, 'description': 'Number of items to return', 'default': 10, 'title': 'Limit'}, 'description': 'Number of items to return'}, {'name': 'cursor', 'in': 'query', 'required': False, 'schema': {'anyOf': [{'type': 'string'}, {'type': 'null'}], 'description': 'Cursor for pagination (base64-encoded JSON string)', 'title': 'Cursor'}, 'description': 'Cursor for pagination (base64-encoded JSON string)'}, {'name': 'workspace_id', 'in': 'query', 'required': False, 'schema': {'anyOf': [{'type': 'string', 'format': 'uuid'}, {'type': 'null'}], 'description': 'Filter by workspace ID', 'title': 'Workspace Id'}, 'description': 'Filter by workspace ID'}, {'name': 'start_time', 'in': 'query', 'required': True, 'schema': {'type': 'string', 'format': 'date-time', 'description': 'Start datetime (inclusive) in ISO 8601 format', 'title': 'Start Time'}, 'description': 'Start datetime (inclusive) in ISO 8601 format'}, {'name': 'end_time', 'in': 'query', 'required': True, 'schema': {'type': 'string', 'format': 'date-time', 'description': 'End datetime (inclusive) in ISO 8601 format', 'title': 'End Time'}, 'description': 'End datetime (inclusive) in ISO 8601 format'}]}}}}
#
# ****************************************************************************************************

# %%
from langchain_text_splitters import  RecursiveJsonSplitter
json_split = RecursiveJsonSplitter(max_chunk_size=300)
json_chucks = json_split.create_documents(texts= [json_data])
for i in json_chucks[:5]:
    print(i,'\n')
    print('*'*100)
# Out:
# page_content='{"openapi": "3.1.0", "info": {"title": "LangSmith", "description": "The LangSmith API is used to programmatically create and manage LangSmith resources.\n\n## Host\nhttps://api.smith.langchain.com\n\n## Authentication\nTo authenticate with the LangSmith API, set the `X-Api-Key` header\nto a valid [LangSmith API key](https://docs.langchain.com/langsmith/create-account-api-key#create-an-api-key).\n\n"}}'
#
# ****************************************************************************************************
# page_content='{"info": {"version": "0.1.0"}, "paths": {"/api/v1/audit-logs": {"get": {"tags": ["audit-logs"], "summary": "Get Audit Logs"}}}}'
#
# ****************************************************************************************************
# page_content='{"paths": {"/api/v1/audit-logs": {"get": {"description": "Retrieve audit log records for the authenticated user's organization in OCSF format.\n\nRequires both start_time and end_time parameters to filter logs within a date range.\nSupports cursor-based pagination.\n\nReturns results in OCSF API Activity (Class UID: 6003) format,\nwhich is compatible with security monitoring and SIEM tools.\nReference: https://schema.ocsf.io/1.7.0/classes/api_activity"}}}}'
#
# ****************************************************************************************************
# page_content='{"paths": {"/api/v1/audit-logs": {"get": {"operationId": "get_audit_logs_api_v1_audit_logs_get", "security": [{"API Key": []}, {"Organization ID": []}, {"Bearer Auth": []}]}}}}'
#
# ****************************************************************************************************
# page_content='{"paths": {"/api/v1/audit-logs": {"get": {"parameters": [{"name": "limit", "in": "query", "required": false, "schema": {"type": "integer", "maximum": 100, "minimum": 1, "description": "Number of items to return", "default": 10, "title": "Limit"}, "description": "Number of items to return"}, {"name": "cursor", "in": "query", "required": false, "schema": {"anyOf": [{"type": "string"}, {"type": "null"}], "description": "Cursor for pagination (base64-encoded JSON string)", "title": "Cursor"}, "description": "Cursor for pagination (base64-encoded JSON string)"}, {"name": "workspace_id", "in": "query", "required": false, "schema": {"anyOf": [{"type": "string", "format": "uuid"}, {"type": "null"}], "description": "Filter by workspace ID", "title": "Workspace Id"}, "description": "Filter by workspace ID"}, {"name": "start_time", "in": "query", "required": true, "schema": {"type": "string", "format": "date-time", "description": "Start datetime (inclusive) in ISO 8601 format", "title": "Start Time"}, "description": "Start datetime (inclusive) in ISO 8601 format"}, {"name": "end_time", "in": "query", "required": true, "schema": {"type": "string", "format": "date-time", "description": "End datetime (inclusive) in ISO 8601 format", "title": "End Time"}, "description": "End datetime (inclusive) in ISO 8601 format"}]}}}}'
#
# ****************************************************************************************************

# %% [markdown]
# # Ollama

# %%
from langchain_community.embeddings import OllamaEmbeddings

embedding = OllamaEmbeddings(model='gemma:2b')

r = embedding.embed_documents([
    'Are you sure',
    'Are you not sure'
])

# %%
print(type(embedding))   # should be <class 'OllamaEmbeddings'>
print(len(r))            # 2
print(len(r[0]))         # embedding dimension
# Out:
# <class 'langchain_community.embeddings.ollama.OllamaEmbeddings'>
# 2
# 2048

# %%
#r[0]

# %%
#r[1]

# %% [markdown]
# # 129. Huggingface Embeddings

# %%
#hf = "Replace this"

# %%
from langchain_huggingface import HuggingFaceEmbeddings

# %%
embeddings = HuggingFaceEmbeddings(model_name = "all-MiniLM-L6-v2")

# %%
text ="Good morning"

# %%
embeddings.embed_query(text)[0]
# Out:
# -0.03337462991476059

# %%
text ="Good mornings"
embeddings.embed_query(text)[0]
# Out:
# -0.048283886164426804

# %% [markdown]
# # 130. VectorStores-FAISS

# %%
from langchain_community.document_loaders import PyPDFLoader
pdf = PyPDFLoader('Offer Letter.pdf')
pdf = pdf.load()

# %%
from langchain_text_splitters import  RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=100)
docs = text_splitter.split_documents(pdf)

# %%
from langchain_community.vectorstores import FAISS

# %%
embedding =OllamaEmbeddings()
db=FAISS.from_documents(docs,embeddings)

# %%
Query = "When the Joining date for this applicate ??"

op = db.similarity_search(Query)
op[0].page_content
# Out:
# '12 July 2024\nNithin kumar K R\nNo 1 \nKothanur\nChikkaballapur\nKarnataka  562105\nDear Nithin kumar,\n \nOffer Letter\nThis has reference to your application and subsequent interview you had with us. Further, we are pleased to offer you the post  \nof Consultant.\n \nKindly make a note that your tentative date of joining would be  29 July 2024  and the Company may be constrained to change  \nyour joining date due to the prevailing unprecedented situation. In that event, the Company shall duly inform you of the revised  \nDate of Joining. In case of any changes to the date of joining please inform us before the expected date of onboard. Failure to  \ninform us and no-show on the expected date of joining will efface this employment offer.\n \nYou shall be on probation for a period of six months starting from the date of your joining. Your performance during the probation  \nwill be appraised and, if found satisfactory, you will be confirmed in services. However, in the event of your performance found'

# %% [markdown]
# # Retriver

# %%
ret = db.as_retriever()

ops  = ret.invoke(Query)

# %%
Query = "When the Joining date for this applicate ??"

op = db.similarity_search_with_score(Query)
#op[0].page_content
op[0][0]
#op[0][1]
# Out:
# Document(id='aad0996e-ebc8-48c0-9fe0-86cc37025304', metadata={'producer': 'LibreOffice 7.6', 'creator': 'Writer', 'creationdate': '2024-07-12T15:50:55+05:30', 'author': 'Hernandez, Mikaela', 'source': 'Offer Letter.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='12 July 2024\nNithin kumar K R\nNo 1 \nKothanur\nChikkaballapur\nKarnataka  562105\nDear Nithin kumar,\n \nOffer Letter\nThis has reference to your application and subsequent interview you had with us. Further, we are pleased to offer you the post  \nof Consultant.\n \nKindly make a note that your tentative date of joining would be  29 July 2024  and the Company may be constrained to change  \nyour joining date due to the prevailing unprecedented situation. In that event, the Company shall duly inform you of the revised  \nDate of Joining. In case of any changes to the date of joining please inform us before the expected date of onboard. Failure to  \ninform us and no-show on the expected date of joining will efface this employment offer.\n \nYou shall be on probation for a period of six months starting from the date of your joining. Your performance during the probation  \nwill be appraised and, if found satisfactory, you will be confirmed in services. However, in the event of your performance found')

# %%
# Saving and Loading 
db.save_local("Faiss_index")

# %%
new_db = FAISS.load_local("Faiss_index", embeddings , allow_dangerous_deserialization=True)

# %%
new_db.similarity_search_with_score(Query)
# Out:
# [(Document(id='aad0996e-ebc8-48c0-9fe0-86cc37025304', metadata={'producer': 'LibreOffice 7.6', 'creator': 'Writer', 'creationdate': '2024-07-12T15:50:55+05:30', 'author': 'Hernandez, Mikaela', 'source': 'Offer Letter.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='12 July 2024\nNithin kumar K R\nNo 1 \nKothanur\nChikkaballapur\nKarnataka  562105\nDear Nithin kumar,\n \nOffer Letter\nThis has reference to your application and subsequent interview you had with us. Further, we are pleased to offer you the post  \nof Consultant.\n \nKindly make a note that your tentative date of joining would be  29 July 2024  and the Company may be constrained to change  \nyour joining date due to the prevailing unprecedented situation. In that event, the Company shall duly inform you of the revised  \nDate of Joining. In case of any changes to the date of joining please inform us before the expected date of onboard. Failure to  \ninform us and no-show on the expected date of joining will efface this employment offer.\n \nYou shall be on probation for a period of six months starting from the date of your joining. Your performance during the probation  \nwill be appraised and, if found satisfactory, you will be confirmed in services. However, in the event of your performance found'),
#   0.8558089),
#  (Document(id='20834c29-8501-4c6f-b697-13cf84a62b4c', metadata={'producer': 'LibreOffice 7.6', 'creator': 'Writer', 'creationdate': '2024-07-12T15:50:55+05:30', 'author': 'Hernandez, Mikaela', 'source': 'Offer Letter.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='Annual Performance Incentive (API) will be paid as per Company’s policies based on Company and individual performance. You  \nwill be eligible from “0%” up to Maximum of “ 10 %”of your annual CTC and the API is subject to deduction of tax at source. You  \nwill be eligible for the pay-out subject to you being a confirmed employee as of 31st Dec and active on the rolls of the company  \nat the time of pay-out without serving any notice period.\nINR 1566009 is the indicative maximum annual earning potential.\nYou will also be eligible to the following on top of the above CTC:\n• Joining Bonus: INR  100000 will be paid after the successful completion of  one month  from the joining date (Subject to  \nappropriate tax) If in case, you resign from the company within 1 year of the date of receipt of the joining bonus the same is  \nrecoverable in full.\n• You will be covered in Group Mediclaim Insurance & Accident Policy Coverage as per policy terms and conditions as relevant'),
#   1.326326),
#  (Document(id='9ae3dd2a-4bba-46d8-afb3-81928f248277', metadata={'producer': 'LibreOffice 7.6', 'creator': 'Writer', 'creationdate': '2024-07-12T15:50:55+05:30', 'author': 'Hernandez, Mikaela', 'source': 'Offer Letter.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='not to be satisfactory, your probation period could be further However, in the event of your performance found not to be  \nsatisfactory, your probation period could be further extended as it deem appropriate by management.\n \nOn Joining, your all-inclusive Cost to the Company (CTC) will be  INR 132917 per month (subject to deduction of tax and other  \nstatutory payments, as may be applicable) as per CTC Annexure. You will also be eligible for all the benefits introduced in the  \nCompany policies, as applicable to your grade.\n \nDuring the probationary period, either party will be entitled to terminate this contract of employment by issuing  15 days days prior \nnotice in writing to the other. After confirmation the termination of employment by either party shall be by issuing  60 days notice \nin writing to the other or salary in lieu thereof. In the event of you issuing a notice of termination shorter than the above period,'),
#   1.4293021),
#  (Document(id='a99bf129-5c79-4cc9-b8d4-0564ba658910', metadata={'producer': 'LibreOffice 7.6', 'creator': 'Writer', 'creationdate': '2024-07-12T15:50:55+05:30', 'author': 'Hernandez, Mikaela', 'source': 'Offer Letter.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='the Company shall have its own discretion to adjust any leave due to you or recover from you such amount from your dues  \ntowards the shortfall in notice period.  However, acceptance of salary in lieu of notice period is at the sole discretion of the  \nCompany.\nIf in case, you resign within a year from the date of your joining, you will be liable to refund the reimbursements such as  \nrelocation expenses, joining bonus, travel expenses [including air & road], accommodation expenses and any other special  \nbenefits as per your eligibility, whichever was provided by the Company.\n \nPlease note that this employment is subject to  professional reference checks and documentary evidence of your previous  \nemployment. \nWe look forward to having you onboard.\nfor SPi Technologies India Private Limited\nManoj P\nVice President – Human Resources\nReceived the offer of employment and shall report for duty on the expected Date of Joining, as mentioned above.\n(Signature with date)'),
#   1.4406369)]

# %% [markdown]
# #  131. VectorStore And Retriever- ChromaDB

# %%
from langchain_chroma import Chroma

# %%
docs
# Out:
# [Document(metadata={'producer': 'LibreOffice 7.6', 'creator': 'Writer', 'creationdate': '2024-07-12T15:50:55+05:30', 'author': 'Hernandez, Mikaela', 'source': 'Offer Letter.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='12 July 2024\nNithin kumar K R\nNo 1 \nKothanur\nChikkaballapur\nKarnataka  562105\nDear Nithin kumar,\n \nOffer Letter\nThis has reference to your application and subsequent interview you had with us. Further, we are pleased to offer you the post  \nof Consultant.\n \nKindly make a note that your tentative date of joining would be  29 July 2024  and the Company may be constrained to change  \nyour joining date due to the prevailing unprecedented situation. In that event, the Company shall duly inform you of the revised  \nDate of Joining. In case of any changes to the date of joining please inform us before the expected date of onboard. Failure to  \ninform us and no-show on the expected date of joining will efface this employment offer.\n \nYou shall be on probation for a period of six months starting from the date of your joining. Your performance during the probation  \nwill be appraised and, if found satisfactory, you will be confirmed in services. However, in the event of your performance found'),
#  Document(metadata={'producer': 'LibreOffice 7.6', 'creator': 'Writer', 'creationdate': '2024-07-12T15:50:55+05:30', 'author': 'Hernandez, Mikaela', 'source': 'Offer Letter.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='not to be satisfactory, your probation period could be further However, in the event of your performance found not to be  \nsatisfactory, your probation period could be further extended as it deem appropriate by management.\n \nOn Joining, your all-inclusive Cost to the Company (CTC) will be  INR 132917 per month (subject to deduction of tax and other  \nstatutory payments, as may be applicable) as per CTC Annexure. You will also be eligible for all the benefits introduced in the  \nCompany policies, as applicable to your grade.\n \nDuring the probationary period, either party will be entitled to terminate this contract of employment by issuing  15 days days prior \nnotice in writing to the other. After confirmation the termination of employment by either party shall be by issuing  60 days notice \nin writing to the other or salary in lieu thereof. In the event of you issuing a notice of termination shorter than the above period,'),
#  Document(metadata={'producer': 'LibreOffice 7.6', 'creator': 'Writer', 'creationdate': '2024-07-12T15:50:55+05:30', 'author': 'Hernandez, Mikaela', 'source': 'Offer Letter.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='the Company shall have its own discretion to adjust any leave due to you or recover from you such amount from your dues  \ntowards the shortfall in notice period.  However, acceptance of salary in lieu of notice period is at the sole discretion of the  \nCompany.\nIf in case, you resign within a year from the date of your joining, you will be liable to refund the reimbursements such as  \nrelocation expenses, joining bonus, travel expenses [including air & road], accommodation expenses and any other special  \nbenefits as per your eligibility, whichever was provided by the Company.\n \nPlease note that this employment is subject to  professional reference checks and documentary evidence of your previous  \nemployment. \nWe look forward to having you onboard.\nfor SPi Technologies India Private Limited\nManoj P\nVice President – Human Resources\nReceived the offer of employment and shall report for duty on the expected Date of Joining, as mentioned above.\n(Signature with date)'),
#  Document(metadata={'producer': 'LibreOffice 7.6', 'creator': 'Writer', 'creationdate': '2024-07-12T15:50:55+05:30', 'author': 'Hernandez, Mikaela', 'source': 'Offer Letter.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='Cost to the Company (CTC) Structure\nName                          :    Nithin kumar K R\nDesignation                :   Consultant\nDepartment                :    Data Analytics\nSALARY COMPUTATION\nComponents Annual Monthly\nBasic Pay 7,14,240 59,520\nHouse Rent Allowance 3,57,120 29,760\nSpecial Allowance 3,57,048 29,754\nGross Salary 14,28,408 1,19,034\nEmployer PF 21,600 1,800\nFixed CTC 14,50,008 1,20,834\nAPI 1,45,001 12,083\nTotal CTC 15,95,009 1,32,917\nEmployee PF 21,600 1,800\nPre Tax Take Home 14,06,808 1,17,234'),
#  Document(metadata={'producer': 'LibreOffice 7.6', 'creator': 'Writer', 'creationdate': '2024-07-12T15:50:55+05:30', 'author': 'Hernandez, Mikaela', 'source': 'Offer Letter.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='Annual Performance Incentive (API) will be paid as per Company’s policies based on Company and individual performance. You  \nwill be eligible from “0%” up to Maximum of “ 10 %”of your annual CTC and the API is subject to deduction of tax at source. You  \nwill be eligible for the pay-out subject to you being a confirmed employee as of 31st Dec and active on the rolls of the company  \nat the time of pay-out without serving any notice period.\nINR 1566009 is the indicative maximum annual earning potential.\nYou will also be eligible to the following on top of the above CTC:\n• Joining Bonus: INR  100000 will be paid after the successful completion of  one month  from the joining date (Subject to  \nappropriate tax) If in case, you resign from the company within 1 year of the date of receipt of the joining bonus the same is  \nrecoverable in full.\n• You will be covered in Group Mediclaim Insurance & Accident Policy Coverage as per policy terms and conditions as relevant'),
#  Document(metadata={'producer': 'LibreOffice 7.6', 'creator': 'Writer', 'creationdate': '2024-07-12T15:50:55+05:30', 'author': 'Hernandez, Mikaela', 'source': 'Offer Letter.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='to your job level/grade.\n• You will be eligible for payment of Gratuity as per the provisions of the Payment of Gratuity Act, 1972.\n• You shall be covered under Group Term Life Insurance (GTLI) policy for a Sum Insured of 2X of your Annual CTC.\nfor SPi Technologies India Private Limited \nManoj P\nVice President – Human Resources\nI accept the above CTC structure breakup and I am aware that this is confidential and shall not disclose this information to  \nothers.\nSignature of Acceptance with date')]

# %%
embedding =OllamaEmbeddings()
db=Chroma.from_documents(docs,embeddings)

# %%
Query = "When the Joining date for this applicate ??"

op = db.similarity_search_with_score(Query)
op[0][0]
# Out:
# Document(id='ccb5ab9e-4d6c-4fe4-8e7a-a4b69a7050e8', metadata={'total_pages': 3, 'page': 0, 'producer': 'LibreOffice 7.6', 'page_label': '1', 'creator': 'Writer', 'source': 'Offer Letter.pdf', 'creationdate': '2024-07-12T15:50:55+05:30', 'author': 'Hernandez, Mikaela'}, page_content='12 July 2024\nNithin kumar K R\nNo 1 \nKothanur\nChikkaballapur\nKarnataka  562105\nDear Nithin kumar,\n \nOffer Letter\nThis has reference to your application and subsequent interview you had with us. Further, we are pleased to offer you the post  \nof Consultant.\n \nKindly make a note that your tentative date of joining would be  29 July 2024  and the Company may be constrained to change  \nyour joining date due to the prevailing unprecedented situation. In that event, the Company shall duly inform you of the revised  \nDate of Joining. In case of any changes to the date of joining please inform us before the expected date of onboard. Failure to  \ninform us and no-show on the expected date of joining will efface this employment offer.\n \nYou shall be on probation for a period of six months starting from the date of your joining. Your performance during the probation  \nwill be appraised and, if found satisfactory, you will be confirmed in services. However, in the event of your performance found')

# %%
vector  = Chroma.from_documents(documents=docs , embedding=embeddings, persist_directory="./chroma_db"z)

# %%
db2 =Chroma(persist_directory="./chroma_db" ,embedding_function=embeddings)
db2.similarity_search_with_score(Query)
# Out:
# [(Document(id='e20dbafd-be4d-4bf5-a887-5817157a0bc7', metadata={'producer': 'LibreOffice 7.6', 'author': 'Hernandez, Mikaela', 'page_label': '1', 'creator': 'Writer', 'total_pages': 3, 'source': 'Offer Letter.pdf', 'page': 0, 'creationdate': '2024-07-12T15:50:55+05:30'}, page_content='12 July 2024\nNithin kumar K R\nNo 1 \nKothanur\nChikkaballapur\nKarnataka  562105\nDear Nithin kumar,\n \nOffer Letter\nThis has reference to your application and subsequent interview you had with us. Further, we are pleased to offer you the post  \nof Consultant.\n \nKindly make a note that your tentative date of joining would be  29 July 2024  and the Company may be constrained to change  \nyour joining date due to the prevailing unprecedented situation. In that event, the Company shall duly inform you of the revised  \nDate of Joining. In case of any changes to the date of joining please inform us before the expected date of onboard. Failure to  \ninform us and no-show on the expected date of joining will efface this employment offer.\n \nYou shall be on probation for a period of six months starting from the date of your joining. Your performance during the probation  \nwill be appraised and, if found satisfactory, you will be confirmed in services. However, in the event of your performance found'),
#   0.8558089733123779),
#  (Document(id='211d6611-5378-4a93-9dd6-f381cf46a9d8', metadata={'source': 'Offer Letter.pdf', 'creationdate': '2024-07-12T15:50:55+05:30', 'total_pages': 3, 'producer': 'LibreOffice 7.6', 'creator': 'Writer', 'author': 'Hernandez, Mikaela', 'page_label': '3', 'page': 2}, page_content='Annual Performance Incentive (API) will be paid as per Company’s policies based on Company and individual performance. You  \nwill be eligible from “0%” up to Maximum of “ 10 %”of your annual CTC and the API is subject to deduction of tax at source. You  \nwill be eligible for the pay-out subject to you being a confirmed employee as of 31st Dec and active on the rolls of the company  \nat the time of pay-out without serving any notice period.\nINR 1566009 is the indicative maximum annual earning potential.\nYou will also be eligible to the following on top of the above CTC:\n• Joining Bonus: INR  100000 will be paid after the successful completion of  one month  from the joining date (Subject to  \nappropriate tax) If in case, you resign from the company within 1 year of the date of receipt of the joining bonus the same is  \nrecoverable in full.\n• You will be covered in Group Mediclaim Insurance & Accident Policy Coverage as per policy terms and conditions as relevant'),
#   1.3263260126113892),
#  (Document(id='7b6b473c-4b16-4aaa-823c-039ce757eabc', metadata={'total_pages': 3, 'creator': 'Writer', 'author': 'Hernandez, Mikaela', 'page_label': '1', 'creationdate': '2024-07-12T15:50:55+05:30', 'page': 0, 'producer': 'LibreOffice 7.6', 'source': 'Offer Letter.pdf'}, page_content='not to be satisfactory, your probation period could be further However, in the event of your performance found not to be  \nsatisfactory, your probation period could be further extended as it deem appropriate by management.\n \nOn Joining, your all-inclusive Cost to the Company (CTC) will be  INR 132917 per month (subject to deduction of tax and other  \nstatutory payments, as may be applicable) as per CTC Annexure. You will also be eligible for all the benefits introduced in the  \nCompany policies, as applicable to your grade.\n \nDuring the probationary period, either party will be entitled to terminate this contract of employment by issuing  15 days days prior \nnotice in writing to the other. After confirmation the termination of employment by either party shall be by issuing  60 days notice \nin writing to the other or salary in lieu thereof. In the event of you issuing a notice of termination shorter than the above period,'),
#   1.4293020963668823),
#  (Document(id='0c92a4af-7a34-413c-9bc9-215ed447b4a3', metadata={'author': 'Hernandez, Mikaela', 'page': 0, 'source': 'Offer Letter.pdf', 'creator': 'Writer', 'producer': 'LibreOffice 7.6', 'page_label': '1', 'creationdate': '2024-07-12T15:50:55+05:30', 'total_pages': 3}, page_content='the Company shall have its own discretion to adjust any leave due to you or recover from you such amount from your dues  \ntowards the shortfall in notice period.  However, acceptance of salary in lieu of notice period is at the sole discretion of the  \nCompany.\nIf in case, you resign within a year from the date of your joining, you will be liable to refund the reimbursements such as  \nrelocation expenses, joining bonus, travel expenses [including air & road], accommodation expenses and any other special  \nbenefits as per your eligibility, whichever was provided by the Company.\n \nPlease note that this employment is subject to  professional reference checks and documentary evidence of your previous  \nemployment. \nWe look forward to having you onboard.\nfor SPi Technologies India Private Limited\nManoj P\nVice President – Human Resources\nReceived the offer of employment and shall report for duty on the expected Date of Joining, as mentioned above.\n(Signature with date)'),
#   1.4406367540359497)]

# %%
db_ = db2.as_retriever()
db_.invoke(Query)
# Out:
# [Document(id='e20dbafd-be4d-4bf5-a887-5817157a0bc7', metadata={'creationdate': '2024-07-12T15:50:55+05:30', 'total_pages': 3, 'source': 'Offer Letter.pdf', 'creator': 'Writer', 'producer': 'LibreOffice 7.6', 'page_label': '1', 'author': 'Hernandez, Mikaela', 'page': 0}, page_content='12 July 2024\nNithin kumar K R\nNo 1 \nKothanur\nChikkaballapur\nKarnataka  562105\nDear Nithin kumar,\n \nOffer Letter\nThis has reference to your application and subsequent interview you had with us. Further, we are pleased to offer you the post  \nof Consultant.\n \nKindly make a note that your tentative date of joining would be  29 July 2024  and the Company may be constrained to change  \nyour joining date due to the prevailing unprecedented situation. In that event, the Company shall duly inform you of the revised  \nDate of Joining. In case of any changes to the date of joining please inform us before the expected date of onboard. Failure to  \ninform us and no-show on the expected date of joining will efface this employment offer.\n \nYou shall be on probation for a period of six months starting from the date of your joining. Your performance during the probation  \nwill be appraised and, if found satisfactory, you will be confirmed in services. However, in the event of your performance found'),
#  Document(id='211d6611-5378-4a93-9dd6-f381cf46a9d8', metadata={'page': 2, 'author': 'Hernandez, Mikaela', 'creator': 'Writer', 'creationdate': '2024-07-12T15:50:55+05:30', 'total_pages': 3, 'producer': 'LibreOffice 7.6', 'page_label': '3', 'source': 'Offer Letter.pdf'}, page_content='Annual Performance Incentive (API) will be paid as per Company’s policies based on Company and individual performance. You  \nwill be eligible from “0%” up to Maximum of “ 10 %”of your annual CTC and the API is subject to deduction of tax at source. You  \nwill be eligible for the pay-out subject to you being a confirmed employee as of 31st Dec and active on the rolls of the company  \nat the time of pay-out without serving any notice period.\nINR 1566009 is the indicative maximum annual earning potential.\nYou will also be eligible to the following on top of the above CTC:\n• Joining Bonus: INR  100000 will be paid after the successful completion of  one month  from the joining date (Subject to  \nappropriate tax) If in case, you resign from the company within 1 year of the date of receipt of the joining bonus the same is  \nrecoverable in full.\n• You will be covered in Group Mediclaim Insurance & Accident Policy Coverage as per policy terms and conditions as relevant'),
#  Document(id='7b6b473c-4b16-4aaa-823c-039ce757eabc', metadata={'creationdate': '2024-07-12T15:50:55+05:30', 'page': 0, 'page_label': '1', 'creator': 'Writer', 'producer': 'LibreOffice 7.6', 'total_pages': 3, 'source': 'Offer Letter.pdf', 'author': 'Hernandez, Mikaela'}, page_content='not to be satisfactory, your probation period could be further However, in the event of your performance found not to be  \nsatisfactory, your probation period could be further extended as it deem appropriate by management.\n \nOn Joining, your all-inclusive Cost to the Company (CTC) will be  INR 132917 per month (subject to deduction of tax and other  \nstatutory payments, as may be applicable) as per CTC Annexure. You will also be eligible for all the benefits introduced in the  \nCompany policies, as applicable to your grade.\n \nDuring the probationary period, either party will be entitled to terminate this contract of employment by issuing  15 days days prior \nnotice in writing to the other. After confirmation the termination of employment by either party shall be by issuing  60 days notice \nin writing to the other or salary in lieu thereof. In the event of you issuing a notice of termination shorter than the above period,'),
#  Document(id='0c92a4af-7a34-413c-9bc9-215ed447b4a3', metadata={'page': 0, 'producer': 'LibreOffice 7.6', 'total_pages': 3, 'source': 'Offer Letter.pdf', 'page_label': '1', 'creator': 'Writer', 'author': 'Hernandez, Mikaela', 'creationdate': '2024-07-12T15:50:55+05:30'}, page_content='the Company shall have its own discretion to adjust any leave due to you or recover from you such amount from your dues  \ntowards the shortfall in notice period.  However, acceptance of salary in lieu of notice period is at the sole discretion of the  \nCompany.\nIf in case, you resign within a year from the date of your joining, you will be liable to refund the reimbursements such as  \nrelocation expenses, joining bonus, travel expenses [including air & road], accommodation expenses and any other special  \nbenefits as per your eligibility, whichever was provided by the Company.\n \nPlease note that this employment is subject to  professional reference checks and documentary evidence of your previous  \nemployment. \nWe look forward to having you onboard.\nfor SPi Technologies India Private Limited\nManoj P\nVice President – Human Resources\nReceived the offer of employment and shall report for duty on the expected Date of Joining, as mentioned above.\n(Signature with date)')]
